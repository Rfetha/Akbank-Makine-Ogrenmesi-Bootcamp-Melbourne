# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Melbourne_housing_FULL.csv")

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (34857, 21)

# %%
len(df.columns)
# Out:
# 21

# %%
df.size
# Out:
# 731997

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount
# count  26881.000000  26881.000000   34854.000000
# mean     -37.810634    145.001851    7572.888306
# std        0.090279      0.120169    4428.090313
# min      -38.190430    144.423790      83.000000
# 25%      -37.862950    144.933500    4385.000000
# 50%      -37.807600    145.007800    6763.000000
# 75%      -37.754100    145.071900   10412.000000
# max      -37.390200    145.526350   21650.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
#  17  Lattitude      26881 non-null  float64
#  18  Longtitude     26881 non-null  float64
#  19  Regionname     34854 non-null  object
#  20  Propertycount  34854 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
print(df.columns, len(df.columns))
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object') 21

# %%
colmNames = ['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
       'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
       'Longtitude', 'Regionname', 'Propertycount']

# %%
df.dropna(subset = ['Distance','Postcode','CouncilArea','Regionname','YearBuilt','Lattitude', 'Longtitude'], inplace = True)
df = df.drop(['Propertycount','SellerG','Address'], axis = 1)
# Out:
# <ipython-input-270-16b798c15c85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset = ['Distance','Postcode','CouncilArea','Regionname','YearBuilt','Lattitude', 'Longtitude'], inplace = True)

# %%
df['Price'].fillna((df['Price'].mean()), inplace = True)
df['Landsize'].fillna((df['Landsize'].mean()), inplace = True)
df['BuildingArea'].fillna((df['BuildingArea'].mean()), inplace = True)
#Catigorical variables
df['Bedroom2'].fillna((df['Bedroom2'].value_counts().index[0]), inplace = True)
df['Bathroom'].fillna((df['Bedroom2'].value_counts().index[0]), inplace = True)
df['Car'].fillna((df['Car'].value_counts().index[0]), inplace = True)

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (8887, 18)
# Suburb          0
# Rooms           0
# Type            0
# Price           0
# Method          0
# Date            0
# Distance        0
# Postcode        0
# Bedroom2        0
# Bathroom        0
# Car             0
# Landsize        0
# BuildingArea    0
# YearBuilt       0
# CouncilArea     0
# Lattitude       0
# Longtitude      0
# Regionname      0
# dtype: int64

# %%
df.describe().T
# Out:
#                count          mean            std           min           25%  \
# Rooms         8887.0  3.098909e+00       0.963786       1.00000       2.00000
# Price         8887.0  1.092902e+06  679381.904112  131000.00000  641000.00000
# Distance      8887.0  1.119989e+01       6.813402       0.00000       6.40000
# Postcode      8887.0  3.111663e+03     112.614268    3000.00000    3044.00000
# Bedroom2      8887.0  3.078204e+00       0.966269       0.00000       2.00000
# Bathroom      8887.0  1.646450e+00       0.721611       1.00000       1.00000
# Car           8887.0  1.692247e+00       0.975464       0.00000       1.00000
# Landsize      8887.0  5.234804e+02    1061.324228       0.00000     212.00000
# BuildingArea  8887.0  1.493095e+02      87.925580       0.00000     100.00000
# YearBuilt     8887.0  1.965753e+03      37.040876    1196.00000    1945.00000
# Lattitude     8887.0 -3.780450e+01       0.090549     -38.17436     -37.85856
# Longtitude    8887.0  1.449914e+02       0.118919     144.42379     144.92000
#
#                       50%           75%           max
# Rooms              3.0000  4.000000e+00  1.200000e+01
# Price         900000.0000  1.345000e+06  9.000000e+06
# Distance          10.2000  1.390000e+01  4.740000e+01
# Postcode        3084.0000  3.150000e+03  3.977000e+03
# Bedroom2           3.0000  4.000000e+00  1.200000e+01
# Bathroom           2.0000  2.000000e+00  9.000000e+00
# Car                2.0000  2.000000e+00  1.000000e+01
# Landsize         478.0000  6.520000e+02  4.280000e+04
# BuildingArea     132.0000  1.800000e+02  3.112000e+03
# YearBuilt       1970.0000  2.000000e+03  2.019000e+03
# Lattitude        -37.7987 -3.774894e+01 -3.740720e+01
# Longtitude       144.9985  1.450646e+02  1.455264e+02

# %%
df.head()
# Out:
#         Suburb  Rooms Type      Price Method       Date  Distance  Postcode  \
# 2   Abbotsford      2    h  1035000.0      S  4/02/2016       2.5    3067.0
# 4   Abbotsford      3    h  1465000.0     SP  4/03/2017       2.5    3067.0
# 6   Abbotsford      4    h  1600000.0     VB  4/06/2016       2.5    3067.0
# 11  Abbotsford      3    h  1876000.0      S  7/05/2016       2.5    3067.0
# 14  Abbotsford      2    h  1636000.0      S  8/10/2016       2.5    3067.0
#
#     Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 2        2.0       1.0  0.0     156.0          79.0     1900.0
# 4        3.0       2.0  0.0     134.0         150.0     1900.0
# 6        3.0       1.0  2.0     120.0         142.0     2014.0
# 11       4.0       2.0  0.0     245.0         210.0     1910.0
# 14       2.0       1.0  2.0     256.0         107.0     1890.0
#
#            CouncilArea  Lattitude  Longtitude             Regionname
# 2   Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 4   Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 6   Yarra City Council   -37.8072    144.9941  Northern Metropolitan
# 11  Yarra City Council   -37.8024    144.9993  Northern Metropolitan
# 14  Yarra City Council   -37.8060    144.9954  Northern Metropolitan

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), cmap = 'viridis', linewidth =1, annot=True, annot_kws = {'size':12})
plt.title('Correlation of features')
# Out:
# <ipython-input-275-27c35942603b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap = 'viridis', linewidth =1, annot=True, annot_kws = {'size':12})
# Text(0.5, 1.0, 'Correlation of features')

# %%
plt.figure(figsize =(15,8))

ax1 = plt.subplot(1,2,1)
sns.boxplot(data=df, x='Type', y='Price')
ax1.set_xlabel('Type')
ax1.set_ylabel('Price')
ax1.set_title('Type vs Price')

ax2 = plt.subplot(1,2,2,sharey=ax1)
sns.boxplot(data=df, x='Method', y='Price')
ax2.set_xlabel('Method')
ax2.set_ylabel('Price')
ax2.set_title('Method vs Price')

#if we look to the graphs there is clearly outliers
# Out:
# Text(0.5, 1.0, 'Method vs Price')

# %%
plt.figure(figsize = (4,8))
sns.boxplot(data=df, y='Price')
# Out:
# <Axes: ylabel='Price'>

# %%
outliers = df[df["Price"] > 2500000]

# %%
df = df[df['Price']<=2500000]
print(df.shape)
df.describe().T
# Out:
# (8514, 18)
#                count           mean            std           min  \
# Rooms         8514.0       3.048039       0.938328       1.00000
# Price         8514.0  997599.470049  480723.825682  131000.00000
# Distance      8514.0      11.344057       6.891190       0.00000
# Postcode      8514.0    3110.622387     114.590264    3000.00000
# Bedroom2      8514.0       3.028776       0.942238       0.00000
# Bathroom      8514.0       1.599836       0.672987       1.00000
# Car           8514.0       1.665844       0.959066       0.00000
# Landsize      8514.0     512.921658    1078.041878       0.00000
# BuildingArea  8514.0     143.041561      75.775861       0.00000
# YearBuilt     8514.0    1966.455250      36.412456    1196.00000
# Lattitude     8514.0     -37.802831       0.091661     -38.17436
# Longtitude    8514.0     144.989620       0.120701     144.42379
#
#                         25%          50%           75%           max
# Rooms              2.000000       3.0000  4.000000e+00  1.200000e+01
# Price         630000.000000  874000.0000  1.281750e+06  2.500000e+06
# Distance           6.500000      10.4000  1.400000e+01  4.740000e+01
# Postcode        3043.000000    3081.0000  3.150000e+03  3.977000e+03
# Bedroom2           2.000000       3.0000  4.000000e+00  1.200000e+01
# Bathroom           1.000000       2.0000  2.000000e+00  9.000000e+00
# Car                1.000000       2.0000  2.000000e+00  1.000000e+01
# Landsize         204.000000     461.5000  6.460000e+02  4.280000e+04
# BuildingArea      98.000000     130.0000  1.740000e+02  1.561000e+03
# YearBuilt       1950.000000    1970.0000  2.000000e+03  2.019000e+03
# Lattitude        -37.857568     -37.7961 -3.774600e+01 -3.740720e+01
# Longtitude       144.915917     144.9961  1.450642e+02  1.455264e+02

# %%
Df = df.copy()

Df.drop(['Date','Suburb','Postcode','YearBuilt'],axis = 1, inplace = True)
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8514 entries, 2 to 34856
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rooms         8514 non-null   int64
#  1   Type          8514 non-null   object
#  2   Price         8514 non-null   float64
#  3   Method        8514 non-null   object
#  4   Distance      8514 non-null   float64
#  5   Bedroom2      8514 non-null   float64
#  6   Bathroom      8514 non-null   float64
#  7   Car           8514 non-null   float64
#  8   Landsize      8514 non-null   float64
#  9   BuildingArea  8514 non-null   float64
#  10  CouncilArea   8514 non-null   object
#  11  Lattitude     8514 non-null   float64
#  12  Longtitude    8514 non-null   float64
#  13  Regionname    8514 non-null   object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 997.7+ KB

# %%
one_hot_encode_Cols = Df.dtypes[Df.dtypes ==np.object]
one_hot_encode_Cols = one_hot_encode_Cols.index.tolist()

print(Df[one_hot_encode_Cols].shape)
Df[one_hot_encode_Cols].head()
# Out:
# (8514, 4)
# <ipython-input-281-50c49c69d78c>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   one_hot_encode_Cols = Df.dtypes[Df.dtypes ==np.object]
#    Type Method         CouncilArea             Regionname
# 2     h      S  Yarra City Council  Northern Metropolitan
# 4     h     SP  Yarra City Council  Northern Metropolitan
# 6     h     VB  Yarra City Council  Northern Metropolitan
# 11    h      S  Yarra City Council  Northern Metropolitan
# 14    h      S  Yarra City Council  Northern Metropolitan

# %%
Df = pd.get_dummies(Df, columns = one_hot_encode_Cols, drop_first = True)
Df.describe().T
# Out:
#                                              count           mean  \
# Rooms                                       8514.0       3.048039
# Price                                       8514.0  997599.470049
# Distance                                    8514.0      11.344057
# Bedroom2                                    8514.0       3.028776
# Bathroom                                    8514.0       1.599836
# Car                                         8514.0       1.665844
# Landsize                                    8514.0     512.921658
# BuildingArea                                8514.0     143.041561
# Lattitude                                   8514.0     -37.802831
# Longtitude                                  8514.0     144.989620
# Type_t                                      8514.0       0.084097
# Type_u                                      8514.0       0.180879
# Method_S                                    8514.0       0.633780
# Method_SA                                   8514.0       0.007165
# Method_SP                                   8514.0       0.148579
# Method_VB                                   8514.0       0.091379
# CouncilArea_Bayside City Council            8514.0       0.035588
# CouncilArea_Boroondara City Council         8514.0       0.075758
# CouncilArea_Brimbank City Council           8514.0       0.048861
# CouncilArea_Cardinia Shire Council          8514.0       0.001409
# CouncilArea_Casey City Council              8514.0       0.004111
# CouncilArea_Darebin City Council            8514.0       0.085271
# CouncilArea_Frankston City Council          8514.0       0.010218
# CouncilArea_Glen Eira City Council          8514.0       0.060019
# CouncilArea_Greater Dandenong City Council  8514.0       0.005990
# CouncilArea_Hobsons Bay City Council        8514.0       0.033474
# CouncilArea_Hume City Council               8514.0       0.045807
# CouncilArea_Kingston City Council           8514.0       0.024548
# CouncilArea_Knox City Council               8514.0       0.012098
# CouncilArea_Macedon Ranges Shire Council    8514.0       0.001292
# CouncilArea_Manningham City Council         8514.0       0.030655
# CouncilArea_Maribyrnong City Council        8514.0       0.057435
# CouncilArea_Maroondah City Council          8514.0       0.012568
# CouncilArea_Melbourne City Council          8514.0       0.051445
# CouncilArea_Melton City Council             8514.0       0.012568
# CouncilArea_Mitchell Shire Council          8514.0       0.000470
# CouncilArea_Monash City Council             8514.0       0.034414
# CouncilArea_Moonee Valley City Council      8514.0       0.064365
# CouncilArea_Moorabool Shire Council         8514.0       0.000117
# CouncilArea_Moreland City Council           8514.0       0.075640
# CouncilArea_Nillumbik Shire Council         8514.0       0.003289
# CouncilArea_Whitehorse City Council         0.000000e+00  1.000000e+00
# CouncilArea_Whittlesea City Council         0.000000e+00  1.000000e+00
# CouncilArea_Wyndham City Council            0.000000e+00  1.000000e+00
# CouncilArea_Yarra City Council              0.000000e+00  1.000000e+00
# CouncilArea_Yarra Ranges Shire Council      0.000000e+00  1.000000e+00
# Regionname_Eastern Victoria                 0.000000e+00  1.000000e+00
# Regionname_Northern Metropolitan            1.000000e+00  1.000000e+00
# Regionname_Northern Victoria                0.000000e+00  1.000000e+00
# Regionname_South-Eastern Metropolitan       0.000000e+00  1.000000e+00
# Regionname_Southern Metropolitan            1.000000e+00  1.000000e+00
# Regionname_Western Metropolitan             0.000000e+00  1.000000e+00
# Regionname_Western Victoria                 0.000000e+00  1.000000e+00

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import KFold, cross_val_predict

# %%
X = Df.drop('Price', axis=1)
y = Df.Price
X.head()
# Out:
#     Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 2       2       2.5       2.0       1.0  0.0     156.0          79.0
# 4       3       2.5       3.0       2.0  0.0     134.0         150.0
# 6       4       2.5       3.0       1.0  2.0     120.0         142.0
# 11      3       2.5       4.0       2.0  0.0     245.0         210.0
# 14      2       2.5       2.0       1.0  2.0     256.0         107.0
#
#     Lattitude  Longtitude  Type_t  ...  CouncilArea_Wyndham City Council  \
# 2    -37.8079    144.9934       0  ...                                 0
# 4    -37.8093    144.9944       0  ...                                 0
# 6    -37.8072    144.9941       0  ...                                 0
# 11   -37.8024    144.9993       0  ...                                 0
# 14   -37.8060    144.9954       0  ...                                 0
#
#     CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council  \
# 2                                1                                       0
# 4                                1                                       0
# 6                                1                                       0
# 11                               1                                       0
# 14                               1                                       0
#
#     Regionname_Eastern Victoria  Regionname_Northern Metropolitan  \
# 2                             0                                 1
# 4                             0                                 1
# 6                             0                                 1
# 11                            0                                 1
# 14                            0                                 1
#
#     Regionname_Northern Victoria  Regionname_South-Eastern Metropolitan  \
# 2                              0                                      0
# 4                              0                                      0
# 6                              0                                      0
# 11                             0                                      0
# 14                             0                                      0
#
#     Regionname_Southern Metropolitan  Regionname_Western Metropolitan  \
# 2                                  0                                0
# 4                                  0                                0
# 6                                  0                                0
# 11                                 0                                0
# 14                                 0                                0
#
#     Regionname_Western Victoria
# 2                             0
# 4                             0
# 6                             0
# 11                            0
# 14                            0
#
# [5 rows x 54 columns]

# %%
kf= KFold(shuffle=True, random_state=72018, n_splits=3)

for train_index, test_index in kf.split(X):
    print('Train index', train_index[:10],len(train_index))
    print('Test Index',test_index[:10], len(test_index))
    print
# Out:
# Train index [ 0  2  3  4  5  7  8  9 10 11] 5676
# Test Index [ 1  6 14 15 16 17 21 22 24 25] 2838
# Train index [ 0  1  2  4  6  7  8  9 10 12] 5676
# Test Index [ 3  5 11 13 18 20 23 30 33 37] 2838
# Train index [ 1  3  5  6 11 13 14 15 16 17] 5676
# Test Index [ 0  2  4  7  8  9 10 12 19 27] 2838

# %%
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor


models = {
    'Lasso': {
    'model': Lasso()
    },
    'LinearRegression': {
    'model': LinearRegression()
    },
    'Ridge': {
    'model': Ridge()
    },
    'ElasticNet': {
    'model': ElasticNet()
    },
    'KNeighborsRegressor': {
    'model': KNeighborsRegressor()
    },
    'RandomForestRegressor': {
    'model': RandomForestRegressor()
    },
    'GradientBoostingRegressor': {
    'model': GradientBoostingRegressor()
    },
    'AdaBoostRegressor': {
    'model': AdaBoostRegressor(n_estimators = 5, learning_rate = 1.2, loss = 'exponential', random_state = 2)
    }
}


keyList = list(models.keys())

# %%
MODELS = []

for i in range(len(models)):
    MODELS.append(models[keyList[i]]["model"])

print(MODELS)
# Out:
# [Lasso(), LinearRegression(), Ridge(), ElasticNet(), KNeighborsRegressor(), RandomForestRegressor(), GradientBoostingRegressor(), AdaBoostRegressor(learning_rate=1.2, loss='exponential', n_estimators=5,
#                   random_state=2)]

# %%
for i in range(len(MODELS)):
    print("Selected model is ", MODELS[i])
# Out:
# Selected model is  Lasso()
# Selected model is  LinearRegression()
# Selected model is  Ridge()
# Selected model is  ElasticNet()
# Selected model is  KNeighborsRegressor()
# Selected model is  RandomForestRegressor()
# Selected model is  GradientBoostingRegressor()
# Selected model is  AdaBoostRegressor(learning_rate=1.2, loss='exponential', n_estimators=5,
#                   random_state=2)

# %%
scores= []

# %%
s= StandardScaler()

for train_index, test_index in kf.split(X):
    X_train,X_test, y_train,y_test = (X.iloc[train_index,:],
                                      X.iloc[test_index,:],
                                      y.iloc[train_index],
                                      y.iloc[test_index])

    for i in range(len(MODELS)):
            lr = MODELS[i]

            X_train_s=s.fit_transform(X_train)
            lr.fit(X_train,y_train)

            X_test_s=s.fit_transform(X_test)
            y_pred = lr.predict(X_test)

            score = r2_score(y_test.values,y_pred)
            scores.append(score)

# %%
len(scores)

for i in range(24):
    print(scores[i])
    if ((i+1)%3 == 0) & (i>0):
        print("\n")
# Out:
# 0.7214495759512585
# 0.7214481410148411
# 0.7210325569061399
#
#
# 0.5262146759207956
# 0.41696349282982437
# 0.839624940775644
#
#
# 0.8231363451171988
# 0.6142109804404872
# 0.7126605928396643
#
#
# 0.7126550295161307
# 0.712794329080604
# 0.5335798890158187
#
#
# 0.41160366465349985
# 0.8314750219218181
# 0.8173606585667977
#
#
# 0.6147292410664797
# 0.7083231361882656
# 0.7083131307858397
#
#
# 0.7078390212906047
# 0.5066450208263524
# 0.41728856231418665
#
#
# 0.8362039151824964
# 0.8127014747047392
# 0.6009416204552904

# %%
best = scores[0]

for x in range(8):
    i = x*3+2

    if scores[i] > best:
        best = scores[i]

print("\nThe best model is: ", MODELS[x])
# Out:
# The best model is:  AdaBoostRegressor(learning_rate=1.2, loss='exponential', n_estimators=5,
#                   random_state=2)
